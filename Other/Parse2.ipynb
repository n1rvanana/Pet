# %%
import requests 
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import numpy as np   
import pandas as pd  
import time          
from fake_useragent import UserAgent
from bs4 import BeautifulSoup
import re
from tqdm import tqdm

# %%
# page_link = 'https://mtgsale.ru/home/search-results?Name=&Lang=Any&Type=Any&Color=Any&Rarity=Any&Foil=Any&minP=3&maxP=34400&Page=5&Sort=name&CardSet='
page_link ='https://scryfall.com/sets'

# %%
UserAgent().chrome
# Out:
# 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/27.0.1453.93 Safari/537.36'

# %%
response = requests.get(page_link, headers={'User-Agent': UserAgent().chrome})
response
# Out:
# <Response [200]>

# %%
html = response.content

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
obj = soup.find_all('td', attrs = {'class':'flexbox'})
# link = obj.find('a').get('href')
# link

# %%
sets_page = []
for single_set in obj:
        set_page = single_set.find('a').get('href')
        if 'http' not in set_page:
            set_page = 'https://scryfall.com'+set_page
        sets_page.append(set_page)
sets_page[:2]
# Out:
# ['https://scryfall.com/sets/gn3', 'https://scryfall.com/sets/unf']

# %%
session = requests.Session()
retry = Retry(connect=5, backoff_factor=1.5)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)

# %%
def getPageLinks(sets_page):
    """
        Возвращает список ссылок на карты mtg, полученный с текущей страницы
        
        page_number: int/string
            номер страницы для парсинга
    """
    
    # составляем ссылку на страницу поиска
    sets_page = []
    cards_page = []
    response = requests.get(page_link, headers={'User-Agent': UserAgent().chrome})
    html = response.content
    soup = BeautifulSoup(html, 'html.parser')
    obj = soup.find_all('td', attrs = {'class':'flexbox'})
    for single_set in obj:
        set_page = single_set.find('a').get('href')
        if 'http' not in set_page:
            set_page = 'https://scryfall.com'+set_page
        sets_page.append(set_page)
        
    sets_page = sets_page[:2]
    
    for set_page in sets_page:
#         print(set_page)
        response = session.get(set_page, headers={'User-Agent': UserAgent().chrome})
        html = response.content
        soup = BeautifulSoup(html,'html.parser')
        cards = soup.findAll(lambda tag: tag.get('class') == ['card-grid-item-card'])
        for link in cards:
#             print(link)
            cards_page.append(link.attrs['href'])
    # запрашиваем данные по ней
    
    
    if not response.ok:
        # если сервер нам отказал, вернем пустой лист для текущей страницы
        return [] 
 
    
    
    return cards_page

# %%
mtg_links = getPageLinks('https://scryfall.com/sets/gn3')
mtg_links[:2]
# Out:
# ['https://scryfall.com/card/gn3/1/zamriel-seraph-of-steel',
#  'https://scryfall.com/card/gn3/2/maeve-insidious-singer']

# %%
stats = [['span', 'card-text-card-name'], ['span', 'card-text-mana-cost'], ['p', 'card-text-type-line'], 
         ['div', 'card-text-oracle'], ['abbr','card-symbol card-symbol-2'], ['abbr','card-symbol card-symbol-U'], 
         ['div', 'card-text-stats'], ['p','card-text-artist'], ['div','card-legality-item']]

# %%
def getStats(soup, stats1, stats2):
    """
        Возвращает очищенные данные
    """
    
    try:
        if stats2 != 'card-legality-item':
            obj = soup.find(stats1, attrs={'class':stats2}).get_text()
            obj = obj.strip()
#         obj = obj.get("title")
#         obj = obj.split()[0]
#         obj = int(obj.replace(',', ''))
        else:
            obj = soup.find_all(stats1, attrs={'class':stats2})
            obj = [x.get_text().strip().split('\n') for x in obj]
            
    except:
        obj=None
    return obj

# %%
def getProperties(link):
    """
        Возвращает список с описанием
    """
    result = []
    response = session.get(link, headers={'User-Agent': UserAgent().chrome})
    html = response.content
    soup = BeautifulSoup(html,'html.parser')
    for stat in stats:
        result.append(getStats(soup, stat[0], stat[1]))
    return result

# %%
rows = getProperties('https://scryfall.com/card/gn3/1/zamriel-seraph-of-steel')
rows
# Out:
# ['Zamriel, Seraph of Steel',
#  '{2}{W}{W}',
#  'Legendary Creature — Angel',
#  'Flying\nAs long as it’s your turn, equipped creatures you control have indestructible.',
#  '{2}',
#  None,
#  '3/4',
#  'Illustrated by\n            Chris Rallis',
#  [['Standard', 'Not Legal'],
#   ['Alchemy', 'Not Legal'],
#   ['Pioneer', 'Not Legal'],
#   ['Explorer', 'Not Legal'],
#   ['Modern', 'Not Legal'],
#   ['Brawl', 'Not Legal'],
#   ['Legacy', 'Legal'],
#   ['Historic', 'Not Legal'],
#   ['Vintage', 'Legal'],
#   ['Pauper', 'Not Legal'],
#   ['Commander', 'Legal'],
#   ['Penny', 'Not Legal']]]

# %%
rows.get_text().strip()

# %%
# final_df = pd.DataFrame(columns=['Language', 'Set', 'Name1', 'Name2', 'Foil',
#                                  'Quality', 'Rarity', 'Price', 'Qty', 'Special1', 'Special2'])
# df_row = 0
# final_df.loc[df_row] = rows[0]

# %%
final_df = pd.DataFrame(columns=['Language', 'Set', 'Name1', 'Name2', 'Foil',
                                 'Quality', 'Rarity', 'Price', 'Qty', 'Special1', 'Special2'])
df_row = 0
session = requests.Session()
retry = Retry(connect=3, backoff_factor=0.5)
adapter = HTTPAdapter(max_retries=retry)
session.mount('http://', adapter)
session.mount('https://', adapter)


for page in tqdm(mtg_links):
    response = session.get(page, headers={'User-Agent': UserAgent().chrome})
    html = response.content
    soup = BeautifulSoup(html,'html.parser')
    rows = getProperties(soup)
    for parsed_row in rows:
#         final_df = pd.DataFrame(columns=['Language', 'Set', 'Name1', 'Name2', 'Foil',
#                                  'Quality', 'Rarity', 'Price', 'Qty', 'Special1', 'Special2'])
        if len(parsed_row) < 11:
            parsed_row = np.insert(parsed_row, 9, '')
        final_df.loc[df_row] = parsed_row
        df_row += 1
final_df
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  7.41it/s]
#       Language                                 Set  \
# 0   Английский                            Unhinged
# 1   Английский                            Unstable
# 2   Английский  Adventures in the Forgotten Realms
# 3   Английский  Adventures in the Forgotten Realms
# 4      Русский  Adventures in the Forgotten Realms
# 5      Русский  Adventures in the Forgotten Realms
# 6      Русский                       Eldritch Moon
# 7      Русский                       Eldritch Moon
# 8      Русский                       Eldritch Moon
# 9      Русский                       Eldritch Moon
# 10  Английский                       Eldritch Moon
# 11  Английский                       Eldritch Moon
# 12     Русский            Innistrad: Midnight Hunt
# 13     Русский            Innistrad: Midnight Hunt
# 14     Русский            Innistrad: Midnight Hunt
# 15     Русский            Innistrad: Midnight Hunt
#
#                          Name1               Name2  Foil Quality     Rarity  \
# 0            "Ach! Hans, Run!"                                NM     Редкая
# 1   "Rumors of My Death . . ."                                NM  Необычная
# 2                      +2 Mace                                NM    Обычная
# 3                      +2 Mace                      Фойл      NM    Обычная
# 4                +2 Mace [RUS]             +2 Mace            NM    Обычная
# 5                +2 Mace [RUS]             +2 Mace  Фойл      NM    Обычная
# 6           Променять Мудрость      Abandon Reason            NM  Необычная
# 7           Променять Мудрость      Abandon Reason            SP  Необычная
# 8           Променять Мудрость      Abandon Reason            MP  Необычная
# 9           Променять Мудрость      Abandon Reason  Фойл      NM  Необычная
# 10              Abandon Reason  Променять Мудрость            NM  Необычная
# 11              Abandon Reason  Променять Мудрость            SP  Необычная
# 12               Покинуть Пост    Abandon the Post            NM    Обычная
# 13               Покинуть Пост    Abandon the Post  Фойл      NM    Обычная
# 14               Покинуть Пост    Abandon the Post            NM    Обычная
# 15               Покинуть Пост    Abandon the Post  Фойл      NM    Обычная
#
#     Price     Qty                                           Special1  \
# 0   370 ₽   1 шт.
# 1     7 ₽  13 шт.
# 2     8 ₽   0 шт.
# 3    18 ₽   2 шт.
# 4     8 ₽   9 шт.
# 5    22 ₽   0 шт.
# 6    14 ₽   3 шт.  Не более двух целевых существ получают по +1/+...
# 7    13 ₽   0 шт.  Не более двух целевых существ получают по +1/+...
# 8    11 ₽   0 шт.  Не более двух целевых существ получают по +1/+...
# 9    45 ₽   0 шт.  Не более двух целевых существ получают по +1/+...
# 10   14 ₽   0 шт.  Не более двух целевых существ получают по +1/+...
# 11   13 ₽   2 шт.  Не более двух целевых существ получают по +1/+...
# 12    8 ₽  14 шт.
# 13   22 ₽   3 шт.
# 14    8 ₽  14 шт.
# 15   22 ₽   3 шт.
#
#                                              Special2
# 0
# 1
# 2                       Equipped creature gets +2/+2.
# 3                       Equipped creature gets +2/+2.
# 4                       Equipped creature gets +2/+2.
# 5                       Equipped creature gets +2/+2.
# 6   Up to two target creatures each get +1/+0 and ...
# 7   Up to two target creatures each get +1/+0 and ...
# 8   Up to two target creatures each get +1/+0 and ...
# 9   Up to two target creatures each get +1/+0 and ...
# 10  Up to two target creatures each get +1/+0 and ...
# 11  Up to two target creatures each get +1/+0 and ...
# 12  Up to two target creatures can't block this turn.
# 13  Up to two target creatures can't block this turn.
# 14  Up to two target creatures can't block this turn.
# 15  Up to two target creatures can't block this turn.

# %%
final_df = pd.DataFrame(columns=['Language', 'Set', 'Name1', 'Name2', 'Foil',
                                 'Quality', 'Rarity', 'Price', 'Qty', 'Special1', 'Special2'])
df_row = 0

# %%
for page_number in tqdm(range(3000, 3734), desc='Pages'):
    # собрали хрефы с текущей страницы
    mtg_links = getPageLinks('https://mtgsale.ru/home/search-results?Page={}', page_number)  
    
    
    
    for mtg_links in mtg_links:
        # иногда с первого раза страничка не парсится
        for i in range(3):
            try:
                # пытаемся собрать по мему немного даты
                
                response = session.get(mtg_links, headers={'User-Agent': UserAgent().chrome})
                
#                 response = requests.get(page, headers={'User-Agent': UserAgent().chrome}) 
                html = response.content
                soup = BeautifulSoup(html,'html.parser')
                rows = getProperties(soup)
                for parsed_row in rows:
                    if len(parsed_row) < 11:
                        parsed_row = np.insert(parsed_row, 9, '')
                    final_df.loc[df_row] = parsed_row
                    df_row += 1
                # если всё получилось - выходим из внутреннего цикла
                break
            except:
                # Иначе, пробуем еще несколько раз, пока не закончатся попытки
                print('AHTUNG! parsing once again:', mtg_links)
                continue
final_df
# Out:
# Pages: 100%|███████████████████████████████████████████████████████████████████████| 734/734 [1:55:30<00:00,  9.44s/it]
#           Language                                 Set  \
# 0       Английский                            Unhinged
# 1       Английский                            Unstable
# 2       Английский  Adventures in the Forgotten Realms
# 3       Английский  Adventures in the Forgotten Realms
# 4          Русский  Adventures in the Forgotten Realms
# ...            ...                                 ...
# 219610  Английский                            Kaladesh
# 219611  Английский                           Darksteel
# 219612  Английский                           Darksteel
# 219613  Английский                           Darksteel
# 219614  Английский              From the Vault: Relics
#
#                              Name1           Name2  Foil Quality      Rarity  \
# 0                "Ach! Hans, Run!"                            NM      Редкая
# 1       "Rumors of My Death . . ."                            NM   Необычная
# 2                          +2 Mace                            NM     Обычная
# 3                          +2 Mace                  Фойл      NM     Обычная
# 4                    +2 Mace [RUS]         +2 Mace            NM     Обычная
# ...                            ...             ...   ...     ...         ...
# 219610            Æther Tradewinds  Эфирный Пассат  Фойл      NM     Обычная
# 219611                  Æther Vial                            NM   Необычная
# 219612                  Æther Vial                            SP   Необычная
# 219613                  Æther Vial                            MP   Необычная
# 219614                  Æther Vial                  Фойл      NM  Мифическая
#
#          Price     Qty Special1  \
# 0        370 ₽   1 шт.
# 1          7 ₽  13 шт.
# 2          8 ₽   0 шт.
# 3         18 ₽   2 шт.
# 4          8 ₽   9 шт.
# ...        ...     ...      ...
# 219610    19 ₽   0 шт.
# 219611  1620 ₽   0 шт.
# 219612  1470 ₽   0 шт.
# 219613  1310 ₽   0 шт.
# 219614  2270 ₽   0 шт.
#
#                                                  Special2
# 0
# 1
# 2                           Equipped creature gets +2/+2.
# 3                           Equipped creature gets +2/+2.
# 4                           Equipped creature gets +2/+2.
# ...                                                   ...
# 219610
# 219611  At the beginning of your upkeep, you may put a...
# 219612  At the beginning of your upkeep, you may put a...
# 219613  At the beginning of your upkeep, you may put a...
# 219614  At the beginning of your upkeep, you may put a...
#
# [219615 rows x 11 columns]

# %%
final_df.to_csv('parsed_data3.csv')
